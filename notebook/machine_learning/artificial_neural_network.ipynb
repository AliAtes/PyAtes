# %%
from IPython.core.display import HTML
HTML(r"""<style> * { color: black !important; font-family: Calibri;  font-size: 20px !important; line-height: 1.5 !important; font-weight: 500; } </style> """)
# Out:
# <style> * { color: black !important; font-family: Calibri;  font-size: 20px !important; line-height: 1.5 !important; font-weight: 500; } </style>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # **Artificial Neural Network - ANN (Yapay Sinir Ağları)**

# %% [markdown]
# ## **Teorik Bilgi**

# %% [markdown]
# ### **T1**<br>

# %% [markdown]
# ## **Uygulama**

# %% [markdown]
# ### **U1**<br>
